# %%
import pandas as pd

# %%
df = pd.read_csv("duos.csv")

# %%
players = df['Player 1'].tolist() + df['Player 2'].tolist()

# %%
players
# Out:
# ['Joe, Isaiah',
#  'Adebayo, Bam',
#  'Pritchard, Payton',
#  'Antetokounmpo, Giannis',
#  'Flynn, Malachi',
#  'DeRozan, DeMar',
#  'Young, Trae',
#  'Culver, Jarrett',
#  'Curry, Stephen',
#  'Brunson, Jalen',
#  'Mitchell, Donovan',
#  'Campazzo, Facundo',
#  'Beasley, Malik',
#  'Harper, Jared',
#  'Harden, James',
#  'Lowry, Kyle',
#  'Nesmith, Aaron',
#  'Smart, Javonte',
#  'Siakam, Pascal',
#  'Dotson, Devon',
#  'Stephenson, Lance',
#  'Jones, Tyus',
#  'Green, Draymond',
#  'Ntilikina, Frank',
#  'Conley, Mike',
#  'Hyland, Bones',
#  'Nowell, Jaylen',
#  'Temple, Garrett']

# %%
p_df = pd.read_csv("namesmodifiedplayerdata.csv")

# %%
p_df.head()
# Out:
#    Unnamed: 0  Rk              Player Pos  Age   Tm   G    MP   PER    TS%  \
# 0           0   1   Achiuwa, Precious   C   22  TOR  73  1725  12.7  0.503
# 1           1   2       Adams, Steven   C   28  MEM  76  1999  17.6  0.560
# 2           2   3        Adebayo, Bam   C   24  MIA  56  1825  21.8  0.608
# 3           3   4       Aldama, Santi  PF   21  MEM  32   360  10.2  0.452
# 4           4   5  Aldridge, LaMarcus   C   36  BRK  47  1050  19.6  0.604
#
#    ...  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP  \
# 0  ...  0.4  2.1  2.5  0.070          NaN  -2.0  -0.6 -2.6  -0.2
# 1  ...  3.8  3.0  6.8  0.163          NaN   1.0   1.0  2.0   2.0
# 2  ...  3.6  3.5  7.2  0.188          NaN   1.7   2.1  3.8   2.7
# 3  ... -0.1  0.4  0.3  0.044          NaN  -4.2  -1.5 -5.7  -0.3
# 4  ...  2.1  1.0  3.1  0.141          NaN   1.3  -0.6  0.7   0.7
#
#    Player-additional
# 0          achiupr01
# 1          adamsst01
# 2          adebaba01
# 3          aldamsa01
# ...

# %%
p_df.describe()
# Out:
#        Unnamed: 0          Rk         Age           G           MP  \
# count  812.000000  812.000000  812.000000  812.000000   812.000000
# mean   405.500000  304.501232   26.052956   36.705665   825.200739
# std    234.548502  172.637333    4.059168   25.898042   775.769997
# min      0.000000    1.000000   19.000000    1.000000     1.000000
# 25%    202.750000  158.750000   23.000000   12.000000   121.000000
# 50%    405.500000  300.500000   25.000000   36.500000   577.500000
# 75%    608.250000  459.000000   29.000000   61.000000  1414.500000
# max    811.000000  605.000000   41.000000   82.000000  2854.000000
#
#               PER         TS%        3PAr         FTr        ORB%  ...  \
# count  812.000000  799.000000  797.000000  797.000000  812.000000  ...
# mean    12.218719    0.527232    0.400491    0.248739    5.402709  ...
# std      7.749585    0.139421    0.236042    0.222867    5.665091  ...
# min    -45.200000    0.000000    0.000000    0.000000    0.000000  ...
# ...

# %%
filtered_df = p_df[p_df["Player"].isin(players)]

# %%
filtered_df.to_csv("dynamicduos.csv")

# %%
filtered_df.describe()
# Out:
#        Unnamed: 0          Rk        Age          G           MP        PER  \
# count   34.000000   34.000000  34.000000  34.000000    34.000000  34.000000
# mean   393.558824  296.470588  26.794118  50.882353  1275.117647  15.735294
# std    243.989095  179.281772   4.643532  23.460818   881.383752   7.500056
# min      2.000000    3.000000  21.000000   4.000000    40.000000   2.500000
# 25%    170.750000  136.750000  22.250000  41.000000   582.750000  10.575000
# 50%    360.500000  269.500000  25.000000  58.500000  1141.000000  15.000000
# 75%    653.250000  491.250000  31.000000  67.750000  2114.250000  20.775000
# max    808.000000  602.000000  35.000000  79.000000  2743.000000  36.900000
#
#              TS%       3PAr        FTr       ORB%  ...  Unnamed: 19  \
# count  34.000000  34.000000  34.000000  34.000000  ...          0.0
# mean    0.545412   0.434588   0.255500   2.720588  ...          NaN
# std     0.069462   0.184327   0.157628   1.610530  ...          NaN
# ...

# %%
p_df['Pos'].unique()
# Out:
# array(['C', 'PF', 'SG', 'PG', 'SF', 'SG-PG', 'SG-SF', 'SF-SG', 'PF-SF',
#        'C-PF', 'SG-PG-SF', 'PG-SG'], dtype=object)

# %%
p_df = p_df.replace(['SG-PG', 'SG-SF', 'SF-SG', 'PF-SF',
       'C-PF', 'SG-PG-SF', 'PG-SG'], ['SG', 'SG', 'SF', 'PF', 'C', 'SG', 'PG'])

# %%
p_df['Pos'].astype('category').cat.codes.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
filtered_df = filtered_df.replace(['SG-PG', 'SG-SF', 'SF-SG', 'PF-SF',
       'C-PF', 'SG-PG-SF', 'PG-SG'], ['SG', 'SG', 'SF', 'PF', 'C', 'SG', 'PG'])

# %%
filtered_df['Pos'].astype('category').cat.codes.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# 0 -> Center, 1-> PF, 2-> PG, 3-> SF, 4-> SG

# %%
#Positional
#0 - guards and shooters, quick and agile
#1 -> versatile players, all-rounders, most efficient players and best players
#2 -> bigs, centers and power forwards
#3 -> weaker players, not heavy contributers

# %%
c_df = pd.read_csv("clusteredplayers.csv")
filtered_df = c_df[c_df["Player"].isin(players)]

# %%
filtered_df['Cluster'].value_counts()
# Out:
# 0    18
# 1    16
# Name: Cluster, dtype: int64
